# %% [markdown]
# <a href="https://colab.research.google.com/github/BibhabenduMukherjee/Python-Oops/blob/main/Floxus_Day_1_Basics_to_Pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
## Importing Pandas Library
import pandas as pd

# %%
#Loading the dataset using pandas
dataframe=pd.read_csv("telecom_churn.csv")

# %%
#Checking for first 5 rows using the head() method
dataframe.head()
# Out:
#   State  Account length  ...  Customer service calls  Churn
# 0    KS             128  ...                       1  False
# 1    OH             107  ...                       1  False
# 2    NJ             137  ...                       0  False
# 3    OH              84  ...                       2  False
# 4    OK              75  ...                       3  False
#
# [5 rows x 20 columns]

# %%
## .info return the datatype of every column
dataframe.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3333 entries, 0 to 3332
# Data columns (total 20 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   State                   3333 non-null   object
#  1   Account length          3333 non-null   int64
#  2   Area code               3333 non-null   int64
#  3   International plan      3333 non-null   object
#  4   Voice mail plan         3333 non-null   object
#  5   Number vmail messages   3333 non-null   int64
#  6   Total day minutes       3333 non-null   float64
#  7   Total day calls         3333 non-null   int64
#  8   Total day charge        3333 non-null   float64
#  9   Total eve minutes       3333 non-null   float64
#  10  Total eve calls         3333 non-null   int64
#  11  Total eve charge        3333 non-null   float64
#  12  Total night minutes     3333 non-null   float64
#  13  Total night calls       3333 non-null   int64
# ...

# %%
#Checking for number of rows and columns
dataframe.shape
# Out:
# (3333, 20)

# %%
#Checking for all the columns
dataframe.columns
# Out:
# Index(['State', 'Account length', 'Area code', 'International plan',
#        'Voice mail plan', 'Number vmail messages', 'Total day minutes',
#        'Total day calls', 'Total day charge', 'Total eve minutes',
#        'Total eve calls', 'Total eve charge', 'Total night minutes',
#        'Total night calls', 'Total night charge', 'Total intl minutes',
#        'Total intl calls', 'Total intl charge', 'Customer service calls',
#        'Churn'],
#       dtype='object')

# %%
#Describing the dataframe. This method displays the basic statistical info about the dataset
dataframe.describe()
# Out:
#        Account length    Area code  ...  Total intl charge  Customer service calls
# count     3333.000000  3333.000000  ...        3333.000000             3333.000000
# mean       101.064806   437.182418  ...           2.764581                1.562856
# std         39.822106    42.371290  ...           0.753773                1.315491
# min          1.000000   408.000000  ...           0.000000                0.000000
# 25%         74.000000   408.000000  ...           2.300000                1.000000
# 50%        101.000000   415.000000  ...           2.780000                1.000000
# 75%        127.000000   510.000000  ...           3.270000                2.000000
# max        243.000000   510.000000  ...           5.400000                9.000000
#
# [8 rows x 16 columns]

# %%
#Selecting a particular column
dataframe[["Total day minutes"]]
# Out:
#       Total day minutes
# 0                 265.1
# 1                 161.6
# 2                 243.4
# 3                 299.4
# 4                 166.7
# ...                 ...
# 3328              156.2
# 3329              231.1
# 3330              180.8
# 3331              213.8
# 3332              234.4
#
# [3333 rows x 1 columns]

# %%
#Viewing a particular row
dataframe.iloc[1]
# Out:
# State                        OH
# Account length              107
# Area code                   415
# International plan           No
# Voice mail plan             Yes
# Number vmail messages        26
# Total day minutes         161.6
# Total day calls             123
# Total day charge          27.47
# Total eve minutes         195.5
# Total eve calls             103
# Total eve charge          16.62
# Total night minutes       254.4
# Total night calls           103
# Total night charge        11.45
# Total intl minutes         13.7
# Total intl calls              3
# Total intl charge           3.7
# Customer service calls        1
# Churn                     False
# Name: 1, dtype: object

# %%
dataframe.iloc[2]
# Out:
# State                        NJ
# Account length              137
# Area code                   415
# International plan           No
# Voice mail plan              No
# Number vmail messages         0
# Total day minutes         243.4
# Total day calls             114
# Total day charge          41.38
# Total eve minutes         121.2
# Total eve calls             110
# Total eve charge           10.3
# Total night minutes       162.6
# Total night calls           104
# Total night charge         7.32
# Total intl minutes         12.2
# Total intl calls              5
# Total intl charge          3.29
# Customer service calls        0
# Churn                     False
# Name: 2, dtype: object

# %% [markdown]
# ## Combining different methods in one cell

# %%
dataframe["Total day minutes"].iloc[1]
# Out:
# 161.6

# %%
dataframe["Total day minutes"].head()
# Out:
# 0    265.1
# 1    161.6
# 2    243.4
# 3    299.4
# 4    166.7
# Name: Total day minutes, dtype: float64

# %%
dataframe["Churn"].value_counts()
# Out:
# False    2850
# True      483
# Name: Churn, dtype: int64

# %%
dataframe.columns
# Out:
# Index(['State', 'Account length', 'Area code', 'International plan',
#        'Voice mail plan', 'Number vmail messages', 'Total day minutes',
#        'Total day calls', 'Total day charge', 'Total eve minutes',
#        'Total eve calls', 'Total eve charge', 'Total night minutes',
#        'Total night calls', 'Total night charge', 'Total intl minutes',
#        'Total intl calls', 'Total intl charge', 'Customer service calls',
#        'Churn'],
#       dtype='object')

# %%
dataframe["International plan"].value_counts()
# Out:
# No     3010
# Yes     323
# Name: International plan, dtype: int64

# %% [markdown]
# ## Sorting the values

# %%
## sort_values(): Sorts the values in the column / Also sorts the dataset according to a particular column

# %%
dataframe.head()
# Out:
#   State  Account length  ...  Customer service calls  Churn
# 0    KS             128  ...                       1  False
# 1    OH             107  ...                       1  False
# 2    NJ             137  ...                       0  False
# 3    OH              84  ...                       2  False
# 4    OK              75  ...                       3  False
#
# [5 rows x 20 columns]

# %%
## Sorting the dataset in ascending order
dataframe.sort_values(by="Total day charge").head()
# Out:
#      State  Account length  ...  Customer service calls  Churn
# 1345    SD              98  ...                       4   True
# 1397    VT             101  ...                       1  False
# 2736    OK             127  ...                       3  False
# 2753    OH             134  ...                       2  False
# 1986    WI              70  ...                       0  False
#
# [5 rows x 20 columns]

# %%
## Sorting the values in descending order
dataframe.sort_values(by="Total day charge", ascending=False).head()
# Out:
#      State  Account length  ...  Customer service calls Churn
# 365     CO             154  ...                       1  True
# 985     NY              64  ...                       1  True
# 2594    OH             115  ...                       1  True
# 156     OH              83  ...                       0  True
# 605     MO             112  ...                       2  True
#
# [5 rows x 20 columns]

# %% [markdown]
# ## mean(): Mean of that respective Column

# %%
dataframe["Total day charge"].mean()
# Out:
# 30.562307230723093

# %%
## Retrieving particular data from the dataframe

# %%
dataframe.head()
# Out:
#   State  Account length  ...  Customer service calls  Churn
# 0    KS             128  ...                       1  False
# 1    OH             107  ...                       1  False
# 2    NJ             137  ...                       0  False
# 3    OH              84  ...                       2  False
# 4    OK              75  ...                       3  False
#
# [5 rows x 20 columns]

# %%
## Selecting particular data from the dataframe

# %%
dataframe[dataframe["Customer service calls"]==1]
# Out:
#      State  Account length  ...  Customer service calls  Churn
# 0       KS             128  ...                       1  False
# 1       OH             107  ...                       1  False
# 8       LA             117  ...                       1  False
# 12      IA             168  ...                       1  False
# 16      ID              85  ...                       1  False
# ...    ...             ...  ...                     ...    ...
# 3313    ID             127  ...                       1  False
# 3314    MO              89  ...                       1  False
# 3317    SD             163  ...                       1  False
# 3324    WV             159  ...                       1  False
# 3326    OH              96  ...                       1  False
#
# [1181 rows x 20 columns]

# %% [markdown]
# ## Selecting dataframe according to a particular condition

# %%
dataframe[dataframe["State"]=="OH"]
# Out:
#      State  Account length  ...  Customer service calls  Churn
# 1       OH             107  ...                       1  False
# 3       OH              84  ...                       2  False
# 152     OH              65  ...                       1  False
# 156     OH              83  ...                       0   True
# 231     OH              63  ...                       1  False
# ...    ...             ...  ...                     ...    ...
# 3249    OH             160  ...                       0  False
# 3251    OH              88  ...                       2  False
# 3286    OH             106  ...                       0  False
# 3325    OH              78  ...                       2  False
# 3326    OH              96  ...                       1  False
#
# [78 rows x 20 columns]

# %%
dataframe[dataframe["Number vmail messages"]>20]
# Out:
#      State  Account length  ...  Customer service calls  Churn
# 0       KS             128  ...                       1  False
# 1       OH             107  ...                       1  False
# 6       MA             121  ...                       3  False
# 9       WV             141  ...                       0  False
# 16      ID              85  ...                       1  False
# ...    ...             ...  ...                     ...    ...
# 3305    IN              58  ...                       2  False
# 3306    AL             106  ...                       1  False
# 3316    MS             103  ...                       0  False
# 3328    AZ             192  ...                       2  False
# 3332    TN              74  ...                       0  False
#
# [813 rows x 20 columns]

# %%
dataframe["International plan"].value_counts()
# Out:
# No     3010
# Yes     323
# Name: International plan, dtype: int64

# %%
dataframe["State"].value_counts()
# Out:
# WV    106
# MN     84
# NY     83
# AL     80
# OH     78
# WI     78
# OR     78
# VA     77
# WY     77
# CT     74
# ID     73
# MI     73
# VT     73
# TX     72
# UT     72
# IN     71
# MD     70
# KS     70
# NC     68
# MT     68
# NJ     68
# WA     66
# NV     66
# CO     66
# MS     65
# RI     65
# MA     65
# AZ     64
# FL     63
# MO     63
# ME     62
# NM     62
# ND     62
# DE     61
# NE     61
# OK     61
# SC     60
# SD     60
# KY     59
# IL     58
# NH     56
# AR     55
# GA     54
# DC     54
# HI     53
# TN     53
# AK     52
# LA     51
# PA     45
# IA     44
# CA     34
# Name: State, dtype: int64

# %%
dataframe.head()
# Out:
#   State  Account length  ...  Customer service calls  Churn
# 0    KS             128  ...                       1  False
# 1    OH             107  ...                       1  False
# 2    NJ             137  ...                       0  False
# 3    OH              84  ...                       2  False
# 4    OK              75  ...                       3  False
#
# [5 rows x 20 columns]

# %%
## Changing the datatype
## .astype(datatype_name)
## int64

# %%
dataframe["Churn"]=dataframe["Churn"].astype("int64")

# %%
dataframe["Churn"].unique()
# Out:
# array([0, 1])

# %%
dataframe.head()
# Out:
#   State  Account length  ...  Customer service calls Churn
# 0    KS             128  ...                       1     0
# 1    OH             107  ...                       1     0
# 2    NJ             137  ...                       0     0
# 3    OH              84  ...                       2     0
# 4    OK              75  ...                       3     0
#
# [5 rows x 20 columns]

# %% [markdown]
# ## Visualization

# %%
## Matplotlib/Seaborn: Used for visualizations

# %%
import seaborn as sns

# %%
## import pandas as pd
## import numpy as np
## import tensorflow as tf

# %%
## countplot: value_counts() in visual form. Bar Graph of the count
## Syntax countplot: sns.countplot("Cloumn_Name", data=dataset_name)

# %%
sns.countplot("Churn", data=dataframe, hue="Churn")
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
dataframe.head()
# Out:
#   State  Account length  ...  Customer service calls Churn
# 0    KS             128  ...                       1     0
# 1    OH             107  ...                       1     0
# 2    NJ             137  ...                       0     0
# 3    OH              84  ...                       2     0
# 4    OK              75  ...                       3     0
#
# [5 rows x 20 columns]

# %%
sns.lineplot(x="Number vmail messages", y="Total day calls", data=dataframe)

# %%
sns.countplot("International plan", data=dataframe, hue="International plan")
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sns.countplot("Voice mail plan", data=dataframe, hue="Voice mail plan")
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
